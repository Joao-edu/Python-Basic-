# %%
nomes_cidades = "São Paulo, Belo Horizonte, Rio de Janeiro, Brasília"
nomes_cidades = nomes_cidades.split(', ')
print(nomes_cidades)
# Out:
# ['São Paulo', 'Belo Horizonte', 'Rio de Janeiro', 'Brasília']

# %%
cabecalho = "               MENU INICIAL            "
print(cabecalho.strip())
# Out:
# MENU INICIAL

# %%
nomes_cidades = 'rIo DE JaNeirO'

print(nomes_cidades.title())
print(nomes_cidades.capitalize())
print(nomes_cidades.lower())
print(nomes_cidades.upper())
# Out:
# Rio De Janeiro
# Rio de janeiro
# rio de janeiro
# RIO DE JANEIRO

# %%
nome_cidade = input('Que cidade de Brasil é conhecidade como caidade maravilhosa?')
nome_cidade = nome_cidade.strip()
while nome_ciade.lower() != 'rio de janeiro' :
    print('Tenta de novo, vai ')
    nome_ciade = input('Que cidade de Brasil é conhecidade como caidade maravilhosa?')
    
print('Booa, Campeão!')
# Out:
# Que cidade de Brasil é conhecidade como caidade maravilhosa?São Paulo
# Tenta de novo, vai
# Que cidade de Brasil é conhecidade como caidade maravilhosa?Belo Horizinte
# Tenta de novo, vai
# Que cidade de Brasil é conhecidade como caidade maravilhosa?Rio dE JaNeIro
# Booa, Campeão!

# %%
mensagem = 'Você vio o que o João disse na sala ontem?'
fui_citado = 'João' in mensagem
print(fui_citado)
# Out:
# True

# %%
mensagem = 'Você vio o que o João disse na sala ontem?'
fui_citado = 'Felipe' in mensagem
print(fui_citado)
# Out:
# False
