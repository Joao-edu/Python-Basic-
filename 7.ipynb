# %% [markdown]
# # Dicionários

# %%
dados_cidade =  {
    'nome'              : 'São Paulo',
    'Estado'            : 'São Paulo',
    'area_km2'          : 1521,
    'populacao_milhoes' : 12.18,
     
}

# %%
print(type(dados_cidade))
# Out:
# <class 'dict'>

# %%
print(dados_cidade)
# Out:
# {'nome': 'São Paulo', 'Estado': 'São Paulo', 'area_km2': 1521, 'populacao_milhoes': 12.18}

# %%
dados_cidade['pais'] = 'Brasil'

# %%
print(dados_cidade)
# Out:
# {'nome': 'Santos', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 15, 'fundacao': '25/01/1554', 'pais': 'Brasil'}

# %%
dados_cidade['area_km2'] = 1500
print(dados_ciade)
# Out:
# {'nome': 'São Paulo', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 12.18}

# %%
dados_cidade_2 = dados_cidade

# %%
dados_ciade_2['nome'] = 'Santos'

# %%
print(dados_cidade_2)
# Out:
# {'nome': 'Santos', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 12.18}

# %%
print(dados_cidade)
# Out:
# {'nome': 'Santos', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 12.18}

# %%
dados_cidade_3 = dados_cidade.copy()

# %%
dados_cidade_3['estado'] = 'Rio de Janeiro'

# %%
print(dados_cidade)
# Out:
# {'nome': 'Santos', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 12.18}

# %%
novos_dados = {
    'populacao_milhoes' : 15,
    'fundacao'          : '25/01/1554'
}

dados_cidade.update(novos_dados)
print(dados_cidade)
# Out:
# {'nome': 'Santos', 'Estado': 'São Paulo', 'area_km2': 1500, 'populacao_milhoes': 15, 'fundacao': '25/01/1554', 'pais': 'Brasil'}

# %%
print(dados_cidade.get('prefeito'))
# Out:
# None

# %%
print(dados_cidade.keys()) # retorna um lista de chaves de um dicionário
print('--------')
print(dados_cidade.values()) # retorna uma lista de valores  de um dicionário
print('--------')
print(dados_cidade.items()) #retorna uma lista de tuplas (Chave, Valores) de um dicionário
# Out:
# dict_keys(['nome', 'Estado', 'area_km2', 'populacao_milhoes', 'fundacao', 'pais'])
# --------
# dict_values(['Santos', 'São Paulo', 1500, 15, '25/01/1554', 'Brasil'])
# --------
# dict_items([('nome', 'Santos'), ('Estado', 'São Paulo'), ('area_km2', 1500), ('populacao_milhoes', 15), ('fundacao', '25/01/1554'), ('pais', 'Brasil')])
