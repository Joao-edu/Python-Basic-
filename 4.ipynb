# %%
empresa = 'Google'
print(empresa)
# Out:
# Google

# %%
empresa = "Gogle"
print(empresa)
# Out:
# Gogle

# %%
mepresa = ('Let's Code)
# Out:
#   File "<ipython-input-4-04e1819686eb>", line 1
#     mepresa = ('Let's Code)
#                     ^
# SyntaxError: invalid syntax

# %%
empresa = ("Let's Code")
print(empresa)
# Out:
# Let's Code

# %%
frase = "O porfessor Pietro da Let's Code disse: "hoje a pizza é porminha conta""

# %%
frase = "O porfessor Pietro da Let's Code disse: \"hoje a pizza é porminha conta\""
print(frase)
# Out:
# O porfessor Pietro da Let's Code disse: "hoje a pizza é porminha conta"

# %%
empresa = 'Google'
print(empresa[0])
# Out:
# G

# %%
print(empresa[:3])
# Out:
# Goo

# %%
nomes_cidades = "São paulo, Balo horizinte, Rio  de Janeiro, Brasília"
nomes-cidades = nomes_cidades.split(', ')
