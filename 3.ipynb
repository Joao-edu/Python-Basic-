# %%
#cria um arrey 
nomes_paises = ['Brasil','Argrntina','China','Canadá','Japão']
print(nomes_paises)
# Out:
# ['Brasil', 'Argrntina', 'China', 'Canadá', 'Japão']

# %%
print("Tamanho da lista", len(nomes_paises))
# Out:
# Tamanho da lista 5

# %%
print('País', nomes_paises[4])

# %%
print('País', nomes_paises[-1])
# Out:
# País Japão

# %%
nomes_paises[4] = 'Colônbia'
print('País', nomes_paises[4])
print(nomes_paises)
# Out:
# País Colônbia
# ['Brasil', 'Argrntina', 'China', 'Canada', 'Colônbia']

# %%
#fatimaneto 

print(nomes_paises[1:3])
# Out:
# ['Argrntina', 'China']

# %%
print(nomes_paises[1:-1])
# Out:
# ['Argrntina', 'China', 'Canada']

# %%
print(nomes_paises[2:])
# Out:
# ['China', 'Canada', 'Colônbia']

# %%
print(nomes_paises[:3])
# Out:
# ['Brasil', 'Argrntina', 'China']

# %%
print(nomes_paises[:])
# Out:
# ['Brasil', 'Argrntina', 'China', 'Canada', 'Colônbia']

# %%
print(nomes_paises[::2])
# Out:
# ['Brasil', 'China', 'Colônbia']

# %%
print(nomes_paises[::-1])
# Out:
# ['Colônbia', 'Canada', 'China', 'Argrntina', 'Brasil']

# %%
print('Brasil' in  nomes_paises)
# Out:
# True

# %%
print('Canadá' not in nomes_paises)
# Out:
# False

# %%
lista_capitais = []

# %%
lista_capitais.append('Brasílisa')
lista_capitais.append('Buenos Aires')
lista_capitais.append('Pequim')
lista_capitais.append('Bogota')

print(lista_capitais)
# Out:
# ['Brasílisa', 'Buenos Aires', 'Pequim', 'Bogota']

# %%
#adiciona capital
lista_capitais.insert(2,'Paris')
print(lista_capitais)
# Out:
# ['Brasílisa', 'Buenos Aires', 'Paris', 'Pequim', 'Bogota']

# %%
#removes campital 
lista_capitais.remove('Paris')
print(lista_capitais)
# Out:
# ['Brasílisa', 'Buenos Aires', 'Pequim', 'Bogota']

# %%
#removes atraves da posição 
removido = lista_capitais.pop(2)
print(lista_capitais, removido)
# Out:
# ['Brasílisa', 'Buenos Aires'] Bogota

# %%
nomes_paises = 'Brasil', 'Argentina', 'China', 'Canadá', 'Japão' 
print(nomes_paises, type(nomes_paises))
