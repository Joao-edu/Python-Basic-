# %%
idade = input ("Informe sua idade")

print(idade, type(idade))
# Out:
# Informe sua idade34
# 34 <class 'str'>

# %%
idade = int(idade)
print(idade, type(idade))
# Out:
# 34 <class 'int'>

# %%
print(float('123.25'))
print(str(123.25))
print(bool(''))
print(bool('abc'))
print(bool(0))
print(bool(-2))
# Out:
# 123.25
# 123.25
# False
# True
# False
# True

# %%
salario_mensal = input('Digite o valor do seu salário: ')
salario_mensal = float(salario_mensal)

gasto_mensal = input('Digite o valor do seu gasto mansal')
gasto_mensal = float(gasto_mensal)

salario_total = salario_mensal * 12 
gasto_total = gasto_mensal * 12

montante_economizado = salario_total - gasto_total
print('O montante o que você pode economizar ao fim do ano é de', montante_economizado)
# Out:
# Digite o valor do seu salário: 5000
# Digite o valor do seu gasto mansal2000
# O montante o que você pode economizar ao fim do ano é de 36000.0
